# %%
import pandas as pd

# %%
modeldata = pd.read_csv('https://raw.githubusercontent.com/tmarchok1/DS440_project/refs/heads/Travis/glogs_final.csv')

modeldata.groupby('day_night')['attendance'].mean()
# Out:
# day_night
# 0    32670.689346
# 1    30100.644318
# Name: attendance, dtype: float64

# %%
modeldata.groupby('made_playoffs')['attendance'].mean()
# Out:
# made_playoffs
# 0    28564.084004
# 1    36739.377394
# Name: attendance, dtype: float64

# %%
modeldata.groupby('won_division')['attendance'].mean()
# Out:
# won_division
# 0    29162.165884
# 1    37984.852062
# Name: attendance, dtype: float64

# %%
v_namedf = modeldata.groupby('h_name')['attendance'].mean().sort_values().to_frame()
v_namedf.plot(kind='bar', y='attendance')
# Out:
# <Axes: xlabel='h_name'>

# %%
winsdf = modeldata.groupby('prev_year_wins')['attendance'].mean().to_frame().reset_index()
winsdf.plot(kind='scatter', x='prev_year_wins', y='attendance')
# Out:
# <Axes: xlabel='prev_year_wins', ylabel='attendance'>

# %%
social = modeldata.groupby('InstagramFollowers')['attendance'].mean().to_frame().reset_index()
social.plot(kind='scatter', x='InstagramFollowers', y='attendance')
# Out:
# <Axes: xlabel='InstagramFollowers', ylabel='attendance'>

# %%
population = modeldata.groupby('CityPopulation')['attendance'].mean().to_frame().reset_index()
population.plot(kind='scatter', x='CityPopulation', y='attendance')
# Out:
# <Axes: xlabel='CityPopulation', ylabel='attendance'>

# %%
capacity = modeldata.groupby('capacity')['attendance'].mean().to_frame().reset_index()
capacity.plot(kind='scatter', x='capacity', y='attendance')
# Out:
# <Axes: xlabel='capacity', ylabel='attendance'>
