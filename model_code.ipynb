# %%
import pandas as pd

# %%
glogs_final = pd.read_csv('https://raw.githubusercontent.com/tmarchok1/DS440_project/refs/heads/Travis/glogs_final.csv')
glogs_final.head()
# Out:
#          date  year  week day_of_week v_name h_name  day_night  \
# 0  2005-04-03  2005     1         Sun    BOS    NYY          1
# 1  2005-04-04  2005     1         Mon    OAK    BAL          0
# 2  2005-04-04  2005     1         Mon    CLE    CHW          0
# 3  2005-04-04  2005     1         Mon     KC    DET          0
# 4  2005-04-04  2005     1         Mon    MIN    SEA          0
#
#               park_id  temp  precip  capacity  prev_year_wins  made_playoffs  \
# 0  Old Yankee Stadium  51.7   0.587   56937.0             101              1
# 1        Camden Yards  60.7   0.000   45971.0              78              0
# 2   US Cellular Field  56.2   0.000   40615.0              83              0
# 3       Comerica Park  59.0   0.000   41083.0              72              0
# 4        Safeco Field  50.1   0.130   47943.0              63              0
#
#    won_division  InstagramFollowers  CityPopulation  attendance
# 0             1             3900000        19940274     54818.0
# 1             0              746000         2859024     48271.0
# 2             0              664000         9408576     38141.0
# 3             0             1000000         4400587     44105.0
# 4             0              927000         4145494     46249.0
