# %%
import pandas as pd
glogs = pd.read_csv(r"C:\Users\jcars\OneDrive\ds capstone\DS440_project\game_logs.csv")
team_wins = pd.read_csv(r"C:\Users\jcars\OneDrive\ds capstone\DS440_project\MLBwins.csv")
# Out:
# C:\Users\jcars\AppData\Local\Temp\ipykernel_14348\218027607.py:2: DtypeWarning: Columns (13,14,15,16,20,21,82,84,86,88,94,95,96,97,98,99,100,101,106,107,109,110,112,113,115,116,118,119,121,122,124,125,127,128,130,131,133,134,136,137,139,140,142,143,145,146,148,149,151,152,154,155,157,158,161) have mixed types. Specify dtype option on import or set low_memory=False.
#   glogs = pd.read_csv(r"C:\Users\jcars\OneDrive\ds capstone\DS440_project\game_logs.csv")

# %%
team_wins
# Out:
#                      Team  2005  2006  2007  2008  2009  2010  2011  2012  \
# 0    Arizona Diamondbacks    77    76    90    82    70    65    94    81
# 1          Atlanta Braves    90    79    84    72    86    91    89    94
# 2       Baltimore Orioles    74    70    69    68    64    66    69    93
# 3          Boston Red Sox    95    86    96    95    95    89    90    69
# 4       Chicago White Sox    99    90    72    89    79    88    79    85
# 5            Chicago Cubs    79    66    85    97    83    75    71    61
# 6         Cincinnati Reds    73    80    72    74    78    91    79    97
# 7     Cleveland Guardians    93    78    96    81    65    69    80    68
# 8        Colorado Rockies    67    76    90    74    92    83    73    64
# 9          Detroit Tigers    71    95    88    74    86    81    95    88
# 10         Houston Astros    89    82    73    86    74    76    56    55
# 11     Kansas City Royals    56    62    69    75    65    67    71    72
# ...
