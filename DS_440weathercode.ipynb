# %%
import pandas as pd

# %%
weather_PHI = pd.read_csv(r'C:\Users\travi\OneDrive\Documents\PennState\classes\2025 spring\DS 440\weather_PHI.csv')
weather_PHI['date'] = pd.to_datetime(weather_PHI['time']).dt.date
weather_PHI['time'] = pd.to_datetime(weather_PHI['time']).dt.time
weather_PHI['city'] = 'Phillies'
weather_PHI.head()
# Out:
#        time  temperature_2m (°F)  relative_humidity_2m (%)  \
# 0  00:00:00                 49.6                        99
# 1  01:00:00                 48.1                        98
# 2  02:00:00                 45.7                        98
# 3  03:00:00                 42.8                        96
# 4  04:00:00                 41.2                        94
#
#    apparent_temperature (°F)  precipitation (inch)  rain (inch)  \
# 0                       43.9                 0.059        0.059
# 1                       41.7                 0.024        0.024
# 2                       36.2                 0.031        0.031
# 3                       31.8                 0.031        0.031
# 4                       31.6                 0.031        0.031
#
#    wind_speed_10m (mp/h)        date          city
# 0                   13.0  2005-04-03  Philadelphia
# 1                   13.9  2005-04-03  Philadelphia
# 2                   19.6  2005-04-03  Philadelphia
# ...
